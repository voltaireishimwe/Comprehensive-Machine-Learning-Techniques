# %% [markdown]
# # Height-Weight Clustering
#
# Dataset: `height_weight_clustering_dataset.csv`
#
# This notebook includes EDA, data cleaning, preprocessing, and modeling for a **Clustering** problem.

# %% [markdown]
# ## 1. Imports & Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## 2. Load & Preview Data

# %%
# Load dataset
df = pd.read_csv('height_weight_clustering_dataset.csv')
#print data shape
print("Data shape:",df.shape)
#print head and tail
print(df.head())
print(df.tail())
# Out:
# Data shape: (1000, 2)
#     height_cm  weight_kg
# 0  173.564333  76.823348
# 1  158.760411  54.644878
# 2  162.354499  60.750420
# 3         NaN  49.693955
# 4  160.787485  41.549540
#       height_cm   weight_kg
# 995  167.365970   55.542900
# 996  179.986663   59.272769
# 997  166.846852   54.250949
# 998  166.708065  116.768694
# 999  157.770981   39.560890

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
# Exploratory Data Analysis
print(df.info())
print(df.describe())
# Missing data visualization
plt.figure(figsize=(10, 4))
sns.heatmap(df.isnull(), cbar=True, yticklabels=False)
plt.title('Missing Values')
plt.show()
# Basic distributions
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(df['height_cm'].dropna(), ax=axes[0], kde=True)
sns.histplot(df['weight_kg'].dropna(), ax=axes[1], kde=True)
plt.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   height_cm  958 non-null    float64
#  1   weight_kg  957 non-null    float64
# dtypes: float64(2)
# memory usage: 15.8 KB
# None
#         height_cm   weight_kg
# count  958.000000  957.000000
# mean   170.008899   69.849642
# std      9.986017   15.387341
# min    140.747874   35.000000
# 25%    163.485165   59.565119
# 50%    170.209716   69.884587
# 75%    176.372298   79.159088
# max    202.929097  185.267688

# %% [markdown]
# ## 4. Data Cleaning & Preprocessing

# %%
# Define preprocessing pipeline
# data cleaning
imputer = SimpleImputer(strategy='median')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
# preprocessing
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_imputed)

# %% [markdown]
# ## 5. Modeling & Evaluation

# %%
# Clustering
df_imputed['cluster'] = clusters
# Fit KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_scaled)
# Visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', alpha=0.7)
plt.colorbar(scatter)
plt.title('KMeans Clustering Results (PCA)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
